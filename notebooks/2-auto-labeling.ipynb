# %% [markdown]
# # Labeling with GPT4o
#
# This notebook labels the samples using the GPT4o model.

# %%
MODEL_OUTPUT = 'gpt4o_outputs_v2'
SPAN_ANNOTATION = 'span_annotations_v2'

# %%
import os 
from openai import OpenAI

KEY = os.environ['OPENAI_KEY']

# %% [markdown]
# Given the length of the samples could affect the labeling performance, I computed the token length of the samples using [Open AI online tokenizer](https://platform.openai.com/tokenizer) and conducted a literature review to find the optimal length of the samples for the GPT4o model, the related papers are listed below. It seems to me our prompt and samples are short enough to be processed in batches.
#
# BABILong: a long-context needle-in-a-haystack benchmark for LLMs
#
# https://github.com/booydar/babilong
#
# https://arxiv.org/pdf/2404.02060
#
# https://github.com/TIGER-AI-Lab/LongICLBench

# %%
system_message = """You are a crowd-source worker who identifies and label hate speech in Turkish tweets. For each tweet, find the hate speech spans targeting the given group and label them with the hate speech category.
Hate Speech Categories:
- Exclusive/Discriminatory Discourse
- Exaggeration; Generalization; Attribution; Distortion 
- Threat of Enmity; War; Attack; Murder; or Harm 
- Symbolization 
- Swearing; Insult; Defamation; Dehumanization
Return a JSON for each tweet:
{ 
	"tweet": {
		"id": "",
		"span": [ 
			{
			"text_span": "",
			"hate_speech_category": ""
			},
			{
			"text_span": "",
			"hate_speech_category": ""
			}
		] 
	}
}
"""

def query_gpt(text):

	
	client = OpenAI(
	    # This is the default and can be omitted
	    api_key=KEY,
	)

	response = client.chat.completions.create(
	    messages=[
	    	{
	    		"role": "system",
	    		"content": system_message,
			},
	        {
	            "role": "user",
	            "content": text,
	        }
	    ],
	    model="gpt-4o-2024-08-06",
	)
	return response.choices[0].message.content


# tweet = '''"
# Tweet id: 1, Target: Kurdish, Text: @shemhamfhorash @aIexstrasza_ @xdomerxd @pusholder Gönül isterdi ki Sinan Oğan kazansın ya da c*p hdpkk safında durmasın, %10 kürt oyu toplayayım diye darmaduman oldular. Beter olsunlar, bunların karşısında bırak RTE'yi taş olsa taşa basarım.\nhttps://t.co/3hHhDqODrr
# Tweet id: 2, Target: Refugee, Text:  Yurt önünde türk yok türk... içeriye anonsla alan bile suriyeli. Bu ne biçim iş. #ülkemdemülteciistemiyorum
# Tweet id: 3, Target: Greek, Text: @username Yunanistan'ın ne kadar borcu var? 1 trilyon dolar? 😂 Umarım savaş başlar ve Türk ordusunun acı gücünü dedelerinizin izmirde tattığı gibi sizde tadarsınız!!! Bu kadar klavye konuşması yeterli. Umarım savaş meydanında karşılaşırız yorgo 😂
# Tweet id: 4, Target: Jew, Text: Filistin-Mısır sınırına itrail saldırı düzenlendi orada da müslümanlar sınıra dayandı diye onlara da saldırmaya başladı kuduz köpek.\n#palestine_egypt\n#filistin_misir https://t.co/r46clGBMs9
# Tweet id: 5, Target: Arab, Text:  @FbVit44 @emredem03 @LuckyBesta Arap sevici yallah çölüne burası Türkiye ve ne mutlu türküm diyeceğiz yallah sen
# Tweet id: 6, Target: Jew, Text: Siz İsrail oğulları hiç mi geçmişinizden ders almazsınız ebabil kuşları nasıl bir fil ordusun yok ettiyse sizinde sonunuzda onların ki gibi olacak !\n\n    #AksadaBaskinVar
# Tweet id: 7, Target: Greek, Text: Yunanistan provokasyon Rumlar kışkırtma peşinde https://t.co/qtUy24gmxq @username aracılığıyla
# Tweet id: 8, Target: Jew, Text: Yorumlarda hintliler " İsrail askeri olarak savşmak istiyorum" yazmışlar. Nedir bu hintlilerdeki itrail aşkı? https://t.co/aO1F2ks4lv
# Tweet id: 9, Target: Refugee, Text: Ya 2-3 gündür denk geliyorum şu suriyeli mevzusunu savunanların çoğunun kadın olması... Yapmayın ablalar yapmayın. Çıkın o elit semtlerinizden suriyeliler afganlar bildiğiniz gibi değil https://t.co/SNjWunjZCe	
# Tweet id: 10, Target: Greek, Text: @Ahaber Dünya Tarihinin En Azametli Tarihini Yazar Şanlı Ecdadimizin Adını Destursuz anan serseriler\n\n""Bu milletin Ferdi Değillerdir""\n\nYoksa kimse Kendi Arasına Sövecek Kadar Aşağılıklaşamaz \n\nBunlar Olsa olsa Yunan Dölü Olması Lazm getir... 
# '''
# output = query_gpt(tweet)

# %%
import pandas as pd

samples = pd.read_csv('../data/hateful_tweets_majority_voting_121024.csv')
samples
# Out:
#       Unnamed: 0                                         hedef_grup derece  \
# 0              0                                  ['Ülke/Milliyet']      4
# 1              3                                  ['Ülke/Milliyet']      6
# 2              6  ['Irk/Etnik Köken', 'Din', 'Hedef grup birden ...      5
# 3              9                                  ['Ülke/Milliyet']      3
# 4             12  ['Belli Görüş/Statü/Uygulama; Mesleki Pozisyon...      0
# ...          ...                                                ...    ...
# 5033       16711  ['Country/Nationality', 'Specific Opinion/Stat...      1
# 5034       16714                            ['Country/Nationality']      4
# 5035       16717  ['Race/Ethnicity', 'Country/Nationality', 'Gen...      6
# 5036       16720  ['Race/Ethnicity', 'Country/Nationality', 'Tar...      6
# 5037       16723              ['Target group is unclear or absent']      7
#
#                                                kategori saldırgan_dil  \
# 0      ['Küfür; Hakaret; Aşağılama; İnsandışılaştırma']         Zayıf
# 1     ['Simgeleştirme', 'Düşmanlık; Savaş; Saldırı; ...           Yok
# 2      ['Küfür; Hakaret; Aşağılama; İnsandışılaştırma']         Zayıf
# 3      ['Küfür; Hakaret; Aşağılama; İnsandışılaştırma']         Zayıf
# 4                         ['Nefret söylemi bulunmuyor']           Yok
# ...                                                 ...           ...
# 5033             ['Exclusive/Discriminatory Discourse']           NaN
# 5034  ['Exclusive/Discriminatory Discourse', 'Symbol...          High
# 5035  ['Exaggeration; Generalization; Attribution; D...          High
# 5036  ['Exaggeration; Generalization; Attribution; D...          High
# 5037  ['Swearing; Insult; Defamation; Dehumanization...           Low
#
#                                              tweet_text     konu  \
# 0                  #Katilİsrail https://t.co/A2uX5Uygxs  Isr-Pal
# 1                  #Katilİsrail https://t.co/IZL3a33jCI  Isr-Pal
# 2     @username @username @username Kur’anda Tevratt...  Isr-Pal
# 3     @veliagbaba Suriyenin iç işlerine karışma, ora...  Isr-Pal
# 4     Akşam haberlerinde "ABD DOĞU AKDENİZ İNİYOR" b...  Isr-Pal
# ...                                                 ...      ...
# 5033  https://ye-now.com/news85294063.html…\nاول ايا...   Arabic
# 5034  العنوسه عندهم ٦٠٪\nال٤٠٪ متزوجين بنغال وهنود و...   Arabic
# 5035  وبعد هالصوره اثبات تسويقهم صار فاشل انكشفو الم...   Arabic
# 5036  الجنسية اليمنية\nأكثر جنسية تم ضبطها\nفي الحمل...   Arabic
# 5037  داخليين السعوديه ومعهم متفجرات ويبون يذبحون ال...   Arabic
#
#                  tweet_id     dil       majority_decision  \
# 0     1353048938450976770     NaN          Yahudi Karşıtı
# 1     1353049567248457729  Türkçe          Yahudi Karşıtı
# 2     1353611898026156032  Türkçe          Yahudi Karşıtı
# 3     1355236074201751554  Türkçe          Yahudi Karşıtı
# 4     1356275317271371776  Türkçe          Yahudi Karşıtı
# ...                   ...     ...                     ...
# 5033  1660028211122561024     NaN  Anti-Immigrant/Refugee
# 5034  1660030789122228225     NaN  Anti-Immigrant/Refugee
# 5035  1660031044723134464     NaN  Anti-Immigrant/Refugee
# 5036  1660070744703868928     NaN  Anti-Immigrant/Refugee
# 5037  1663559853313515523     NaN  Anti-Immigrant/Refugee
#
#                                        tweet_text_clean
# 0                                         #Katilİsrail
# 1                                         #Katilİsrail
# 2        Kur’anda Tevratta derki itrail oğulları ask...
# 3      Suriyenin iç işlerine karışma, orada konuşlan...
# 4     Akşam haberlerinde "ABD DOĞU AKDENİZ İNİYOR" b...
# ...                                                 ...
# 5033  \nاول ايام ذو القعدة الكابوس للمغتربين العاملي...
# 5034  العنوسه عندهم ٦٠٪\nال٤٠٪ متزوجين بنغال وهنود و...
# 5035  وبعد هالصوره اثبات تسويقهم صار فاشل انكشفو الم...
# 5036  الجنسية اليمنية\nأكثر جنسية تم ضبطها\nفي الحمل...
# 5037  داخليين السعوديه ومعهم متفجرات ويبون يذبحون ال...
#
# [5038 rows x 11 columns]

# %%
samples['majority_decision'].value_counts()
# Out:
# majority_decision
# Göçmen/Mülteci Karşıtı    1259
# Yahudi Karşıtı            1200
# Yunan Karşıtı             1121
# Ermeni Karşıtı             635
# Arap Karşıtı               338
# Anti-Immigrant/Refugee     245
# Alevi Karşıtı              127
# Kürt Karşıtı                64
# LGBTI+ Karşıtı              49
# Name: count, dtype: int64

# %%
translations = {
    'Göçmen/Mülteci Karşıtı': 'Immigrant/Refugee',
    'Yunan Karşıtı': 'Greek',
    'Yahudi Karşıtı': 'Jew',
    'Ermeni Karşıtı': 'Armenian',
    'Arap Karşıtı': 'Arab',
    'LGBTI+ Karşıtı': 'LGBTI+',
    'Kürt Karşıtı': 'Kurdish',
    'Alevi Karşıtı': 'Alevi'
}

samples['target'] = samples['majority_decision'].map(translations)

# %%
targets = samples['target'].unique()
targets
# Out:
# array(['Jew', 'Greek', 'Immigrant/Refugee', nan, 'Alevi', 'Arab',
#        'Armenian', 'Kurdish', 'LGBTI+'], dtype=object)

# %%
samples['model_input'] = samples.apply(lambda x: f"Tweet id: {x['tweet_id']}, Target: {x['target']}, Text: {x['tweet_text']}", axis=1)

# %%
samples = samples.dropna(subset=['target'])
samples['target'].value_counts()
# Out:
# target
# Immigrant/Refugee    1259
# Jew                  1200
# Greek                1121
# Armenian              635
# Arab                  338
# Alevi                 127
# Kurdish                64
# LGBTI+                 49
# Name: count, dtype: int64

# %%
print(samples[samples['target'] == 'LGBTI+']['model_input'].str.cat(sep='\n'))
# Out:
# Tweet id: 1657927550855773952, Target: LGBTI+, Text: Beni rahatsız eden her işlerinde bir şeytanlık var, halkı düşünüyormuş gibi yapmaları insanların özel hayatlarını deşifre etmesi ama kendilerinin sapık ve bir çoğunun biseksüel olması,bunların hepsinin hainlikte rızası var
# Tweet id: 1658005454822285056, Target: LGBTI+, Text: @bernalacin35 Defol şeytan CHP pkk lgbt lilere versinler şu sapık zihniyete bak sen geberdiğinde görürsün kim hak ediyor kıyametin kopacak artık son pişmanlık fayda etmez yol yekınken tövbe et rabbine sarıl dinsiz imansız gitme öbür tarafa
# Tweet id: 1658005670178725888, Target: LGBTI+, Text: @MAturkce Duygu sümürüsü para etmedi. 6 milyon oy 4 milyona indi. Sadece Êvdocularin; sapık karisiz kocasiz, LGBT'li olmak, devletsiz, kimliksiz, dünyayı deyiştime solculuk fikirlerinin kürde dayatması  yüzünde daha çok küdü kaybedecektir. Kürdü çantada keklik  gören aptallar bitecek....
# Tweet id: 1658015459822690048, Target: LGBTI+, Text: @AlparslanCansiz @nevsinmengu Türk kadını siha,iha,helikopter,tank ,uçak yapıyor.Kullanıyor.
# Okuyor,okutuyor,çocuk yetiştiriyor.
# Kadın kadına tarzı LGBTİ den bahsediyorsanız Türk kadını tarihte de bugün de sapkın olmamıştır.
# Tweet id: 1658017413860844032, Target: LGBTI+, Text: @flora7169 @millasofsong @furkancerkes Evet bugün için canını veren şehitlerimiz için Cumhur ittifakını destekledim. Teröristlerle, sapkın lgbtcilerle birlik olanları desteklemedim. Utan utan şehitlerimizin kanını döken HDP ile birlik olan, terörist başlarına özgürlük isteyen sizsiniz !!
# Tweet id: 1658028859759943936, Target: LGBTI+, Text: @jevlyin @DisiaslanI9o5 @LayluNada @ekrem_imamoglu Ulan profilinde l*gbt renkleri var. Sapkınlığın en âlâsı sizsiniz. Bu ülke sizden nasıl kurtulacağını tartışmalı. Senin zihniyetin bu ülkenin gençliğinin altına döşenmiş bir dinamittir. Ama gün gelecek hiç biriniz bu ülkede yer bulamayacaksınız. Sapkın zihniyetliler sizi.
# Tweet id: 1658029106632457984, Target: LGBTI+, Text: @ReyyanBilge Sadece dindara söz söyleyenlere bölücü CHPKK ne dersiniz  sapkın Lbgt destekleyenlere ne dersiniz
# Yatacak yeriniz yok bunlara sözünüz yok mu
# Tweet id: 1658029129579494912, Target: LGBTI+, Text: @omerhankrm Özündeki meziyetlerden kasıt nedir lgbt gibi sapkın şeyleri desteklemek mi zannediyorsun kuranı bu işleri alet etmeyin tırnakla ayet çekip bunu da kendinizi destekler gibi paylaşmayın
# Ne verdiğiniz HDP ve selo desteğinize , ne fetöcülere verdiğiniz desteğe, ne de lgbt vb sapkın görüşlere verdiğiniz desteğe saygım yok. Sizin yüzünüzden çocuklarımın geleceği için endişeleniyorum. inş. Erdoğan galip gelerek bu saçmalıklarınızı susturacak!
# Tweet id: 1658446081003322880, Target: LGBTI+, Text: @cumhuriyetgzt @siring Herşeyden önce anneyim
# Ne verdiğiniz HDP ve selo desteğinize , ne fetöcülere verdiğiniz desteğe, ne de lgbt vb sapkın görüşlere verdiğiniz desteğe saygım yok. Sizin yüzünüzden çocuklarımın geleceği için endişeleniyorum. inş. Erdoğan galip gelerek bu saçmalıklarınızı susturacak!
# Tweet id: 1658453859868590080, Target: LGBTI+, Text: Ahhh hocalar Ahhhh LGBT lilere sert çıkışlar yapıpta, onlara bu sapkın hakları veren AKP yi, bırakın eleştirmeyi, büyük bir aşkla ve şevkle desteklemenizi hangi akıl ve izanla ifade edeceksiniz.
# Gerçekten aklım almıyor. https://t.co/hiUJSrPyNy
# Tweet id: 1658552764673163008, Target: LGBTI+, Text: @hsynguvenn @rsmeyraa Elbette ki Hüseyin bey.
# Öncelikle “başörtüsünün ve tesettürün anayasal güvenceye kavuşturulması”, “ailenin sapkın anlayışlara karşı korunması”, “6284 sayılı yasanın değiştirilmesi”, “süresiz nafaka uygulamasına son verilmesi”,++
# Tweet id: 1658554029532667904, Target: LGBTI+, Text: @hsynguvenn @rsmeyraa Sapkın anlayışlara karşı korumak fikriyse devletin insanlara yalnızca bir fikri empoze etme çabasıdır. Şöyle düşünmeniz daha doğru olur: Türkiye Cumhuriyetinin kadın ve erkeğin evliliğini yasakladığını ve yalnızca aynı cinsiyetten evliliklerin geçerli olduğunu bu haksızlıktır.
# Tweet id: 1658575026314936064, Target: LGBTI+, Text: Alman bir Lpg'ci, Münih Devlet kütüphanesinde bazı politikacılar öncülüğünde protesto edilmesine rağmen,
# 4 yaşındaki çocuklara sapık masallar okuyacak.
#
# Ey Rabbim, neslimize sahip çık, bunlara fırsat verme Allahım... https://t.co/yisJj2nGjB
# Tweet id: 1658577720995880960, Target: LGBTI+, Text: #biz16milyonuz Şırnak bestler dereler öğretmenler Oğuzhan Uğur  #OylarYenidenSayilsin   Orhan Gencebay millet ittifakı Sezen Aksu
# "Dualar baby için izlemişler. Bir doğuştan çift cinsiyet  için hep beraber lgbtli olalım istiyorlar. Siz duyarlı değilsiniz. Siz sapık ve salaksınız "
# Tweet id: 1658598143657689088, Target: LGBTI+, Text: @SosyalBedevi27 😁 Öğretmişler bunlara DEMOKRASİ kelimesini,  bu kelimenin altında her türlü sapık fikirleri ve bölücülüğü halka enjekte edecekler. Demokrasi maskesinin arkasında VATANSIZLIK, CİNSİYETSİZLİK,DİNSİZLİK vs..
# Tweet id: 1658614545672204032, Target: LGBTI+, Text: @sozgurk Sinan Oğan destekçilerini aktrollerle karıştırmış . Bizim kitlede ne bunlar gibi gizli Gay ne sapkın bulunmaz .
# Tweet id: 1658706680719319040, Target: LGBTI+, Text: @furkancerkes Yaa ne alakası var benim kız kardeşim başı açık benim örtülü ikimizde aynı siyasi değerleri taşıyoruz 28 Şubat'ı unuttugumuzu sanıyorlar biz lgbt sapkın akımlar dışında açık kapalı gözetmeksizin bir birimizi seviyoruz kendi pisliğini bizim üstümüze yıkıyorlar.. ahlaksız zihinler.
# Tweet id: 1658729108950401024, Target: LGBTI+, Text: @eylulttuzun @gusholderhaber Lgbt gibi bir sapkın akımı destekleyen kim? Kemal Kılıçdaroğlu. Daha yaptığı tonla saçmalığı saysak heralde sabah kadar sayarız. Umarım gözleriniz açılır bir gün 🙏
# Tweet id: 1658742896118432000, Target: LGBTI+, Text: @lacrimosa666xx @GkmnDerya @Uzaktan_Gelen_ Cinsel yönelim demeyelim de hastalıklı sapkın ilişki yaşayan  psikolojik sorunları olan bireyler diyelim ,bu tiplerin toplum içinde yaygınlaşması ve reklamının yapılması turk İslam geleneğine ve aile yapısına ters, okuma konusuna gelince kurduğum cümlelerden anlamanı bekliyordum

# %%
targets = ['Arab', 'Armenian', 'Greek', 'Jew', 'Immigrant/Refugee', 'Alevi', 'Kurdish',  'LGBTI+' ]

# %%
from tqdm import tqdm
for target in targets:
    df = samples[samples['target'] == target]
    for input, tweet_id in tqdm(zip(df['model_input'].to_list(), df['tweet_id'].to_list())):
        try: 
            output = query_gpt(input)
            with open(f'../data/{MODEL_OUTPUT}/{target.replace("/", "-")}_{tweet_id}.json', 'w', encoding='utf-8') as f:
                f.write(output.strip('`').replace('json', ''))
        except: 
            pass

# %%
# dictionary to tweet id to text
id2text = samples.set_index('tweet_id')['tweet_text'].to_dict()

# %%
from pathlib import Path    
import json 

OUTPUT_PATH = Path(f'../data/{MODEL_OUTPUT}')

for target in targets:
    tweets = []
    for file in OUTPUT_PATH.iterdir():
        if target in file.name: 
            with open((OUTPUT_PATH / file.name.replace("/", "-")), 'r', encoding='utf-8') as f:
                data = json.load(f)
                try:
                    data['tweet']['text'] = id2text[int(data['tweet']['id'])]
                except KeyError:
                    print(f"Tweet id {tweet_id} not found")
                tweets.append(data)     
    with open(f'../data/{SPAN_ANNOTATION}/{target.replace("/", "-")}.json', 'w', encoding='utf-8') as f:
        json.dump(tweets, f, ensure_ascii=False, indent=4)

# %%
import json 
import pandas as pd 

for target in targets:
    records = []
    with open(f'../data/{SPAN_ANNOTATION}/{target.replace("/", "-")}.json', 'r', encoding='utf-8') as f:
        data = json.load(f)
        for instance in data:
            try:
                tweet_id = instance['tweet']['id']
                text = instance['tweet']['text']
                spans = instance['tweet']['span']
                span_txt = ",".join([f"{span['text_span']}" for span in spans])
                category_txt = ",".join([f"{span['hate_speech_category']}" for span in spans])
                records.append([tweet_id, target, text, span_txt, category_txt])
            except KeyError:
                print(f"Tweet id {tweet_id} not found")
    df = pd.DataFrame(records, columns=['tweet_id', 'target', 'text', 'span', 'category'])
    df.to_csv(f'../data/{SPAN_ANNOTATION}/{target.replace("/", "-")}.csv', index=False)
