# %% [markdown]
# # Labeling with GPT4o
#
# This notebook labels the samples using the GPT4o model.

# %%
import os 
from openai import OpenAI

KEY = os.environ["OPENAI_KEY"]

# %% [markdown]
# Given the length of the samples could affect the labeling performance, I computed the token length of the samples using [Open AI online tokenizer](https://platform.openai.com/tokenizer) and conducted a literature review to find the optimal length of the samples for the GPT4o model, the related papers are listed below. It seems to me our prompt and samples are short enough to be processed in batches.
#
# BABILong: a long-context needle-in-a-haystack benchmark for LLMs
#
# https://github.com/booydar/babilong
#
# https://arxiv.org/pdf/2404.02060
#
# https://github.com/TIGER-AI-Lab/LongICLBench

# %%
system_message = """You are a crowd-source worker who identifies and label hate speech in Turkish tweets. For each tweet, find the hate speech spans targeting the given group and label them with the hate speech category.
Hate Speech Categories:
- Exclusive/Discriminatory Discourse
- Exaggeration; Generalization; Attribution; Distortion 
- Threat of Enmity; War; Attack; Murder; or Harm 
- Symbolization 
- Swearing; Insult; Defamation; Dehumanization
Return a JSON for each tweet:
{
  "hate_speech_instances": [
    { 
      "tweet": {
         "id": "",
		 "span": [ 
            "text_span": "",
            "hate_speech_category": ""
		] 
	  }
    },
	{
	   "tweet": {
         "id": "",
		 "span": [ 
            "text_span": "",
            "hate_speech_category": ""
		] 
	  }
	}
  ]
}
"""

def query_gpt(text):

	
	client = OpenAI(
	    # This is the default and can be omitted
	    api_key=KEY,
	)

	response = client.chat.completions.create(
	    messages=[
	    	{
	    		"role": "system",
	    		"content": system_message,
			},
	        {
	            "role": "user",
	            "content": text,
	        }
	    ],
	    model="gpt-4o-2024-05-13", #"gpt-4o-2024-05-13",
	)

	return response.choices[0].message.content


# tweet = '''"
# Tweet id: 1, Target: Kurdish, Text: @shemhamfhorash @aIexstrasza_ @xdomerxd @pusholder Gönül isterdi ki Sinan Oğan kazansın ya da c*p hdpkk safında durmasın, %10 kürt oyu toplayayım diye darmaduman oldular. Beter olsunlar, bunların karşısında bırak RTE'yi taş olsa taşa basarım.\nhttps://t.co/3hHhDqODrr
# Tweet id: 2, Target: Refugee, Text:  Yurt önünde türk yok türk... içeriye anonsla alan bile suriyeli. Bu ne biçim iş. #ülkemdemülteciistemiyorum
# Tweet id: 3, Target: Greek, Text: @username Yunanistan'ın ne kadar borcu var? 1 trilyon dolar? 😂 Umarım savaş başlar ve Türk ordusunun acı gücünü dedelerinizin izmirde tattığı gibi sizde tadarsınız!!! Bu kadar klavye konuşması yeterli. Umarım savaş meydanında karşılaşırız yorgo 😂
# Tweet id: 4, Target: Jew, Text: Filistin-Mısır sınırına itrail saldırı düzenlendi orada da müslümanlar sınıra dayandı diye onlara da saldırmaya başladı kuduz köpek.\n#palestine_egypt\n#filistin_misir https://t.co/r46clGBMs9
# Tweet id: 5, Target: Arab, Text:  @FbVit44 @emredem03 @LuckyBesta Arap sevici yallah çölüne burası Türkiye ve ne mutlu türküm diyeceğiz yallah sen
# Tweet id: 6, Target: Jew, Text: Siz İsrail oğulları hiç mi geçmişinizden ders almazsınız ebabil kuşları nasıl bir fil ordusun yok ettiyse sizinde sonunuzda onların ki gibi olacak !\n\n    #AksadaBaskinVar
# Tweet id: 7, Target: Greek, Text: Yunanistan provokasyon Rumlar kışkırtma peşinde https://t.co/qtUy24gmxq @username aracılığıyla
# Tweet id: 8, Target: Jew, Text: Yorumlarda hintliler " İsrail askeri olarak savşmak istiyorum" yazmışlar. Nedir bu hintlilerdeki itrail aşkı? https://t.co/aO1F2ks4lv
# Tweet id: 9, Target: Refugee, Text: Ya 2-3 gündür denk geliyorum şu suriyeli mevzusunu savunanların çoğunun kadın olması... Yapmayın ablalar yapmayın. Çıkın o elit semtlerinizden suriyeliler afganlar bildiğiniz gibi değil https://t.co/SNjWunjZCe	
# Tweet id: 10, Target: Greek, Text: @Ahaber Dünya Tarihinin En Azametli Tarihini Yazar Şanlı Ecdadimizin Adını Destursuz anan serseriler\n\n""Bu milletin Ferdi Değillerdir""\n\nYoksa kimse Kendi Arasına Sövecek Kadar Aşağılıklaşamaz \n\nBunlar Olsa olsa Yunan Dölü Olması Lazm getir... 
# '''
# output = query_gpt(tweet)

# %%
import pandas as pd

samples = pd.read_csv('../data/span_samples_v3.csv')
samples
# Out:
#                 genel_tutum  \
# 0    Anti-Immigrant/Refugee
# 1    Anti-Immigrant/Refugee
# 2              Arap Karşıtı
# 3              Arap Karşıtı
# 4              Arap Karşıtı
# ..                      ...
# 247           Yunan Karşıtı
# 248           Yunan Karşıtı
# 249           Yunan Karşıtı
# 250           Yunan Karşıtı
# 251           Yunan Karşıtı
#
#                                             hedef_grup derece  \
# 0                              ['Country/Nationality']      6
# 1                              ['Country/Nationality']      7
# 2                 ['Irk/Etnik Köken', 'Ülke/Milliyet']      5
# 3                                  ['Irk/Etnik Köken']      4
# 4                                  ['Irk/Etnik Köken']      3
# ..                                                 ...    ...
# 247                                ['Irk/Etnik Köken']      7
# 248                                ['Irk/Etnik Köken']      8
# 249  ['Irk/Etnik Köken', 'Ülke/Milliyet', 'Din', 'H...      7
# 250                                ['Irk/Etnik Köken']      6
# 251                                ['Irk/Etnik Köken']      5
#
#                                               kategori saldırgan_dil  \
# 0    ['Swearing; Insult; Defamation; Dehumanization...           Low
# 1    ['Exaggeration; Generalization; Attribution; D...           Low
# 2            ['Abartma; Genelleme; Yükleme; Çarpıtma']           Yok
# 3                                    ['Simgeleştirme']         Zayıf
# 4            ['Abartma; Genelleme; Yükleme; Çarpıtma']           Yok
# ..                                                 ...           ...
# 247                                  ['Simgeleştirme']      Şiddetli
# 248  ['Simgeleştirme', 'Düşmanlık; Savaş; Saldırı; ...      Şiddetli
# 249   ['Küfür; Hakaret; Aşağılama; İnsandışılaştırma']      Şiddetli
# 250   ['Küfür; Hakaret; Aşağılama; İnsandışılaştırma']      Şiddetli
# 251                                  ['Simgeleştirme']           Yok
#
#                                             tweet_text annotator  \
# 0    بالآونه الاخيرة اكثر الحسابات المتنكرة كسعوديي...      Neda
# 1    دخولهم الى دولنا خطير بسبب \nاعمال السحر والشع...      Neda
# 2    @muhendisyenn Hemde çok büyük bir sorun var. B...      Şura
# 3    En milliyetçi adamlardan biriyim ama asla mill...   Firdevs
# 4    @championoneday @secimtr2023 Kendi milletimden...      Şura
# ..                                                 ...       ...
# 247  @ARZU61__ @fikretk53429081 @YukselisGruplar #Y...     Ebrar
# 248  HEPSİ YUNAN TOHUMU ,HEPSİ TERÖRİST https://t.c...     Aygün
# 249  @username SOYSUZ SOYKIRIMCI YUNAN.MÜSLÜMAN TÜR...     Altar
# 250  @username @username @username Sen anca bok yer...      İpek
# 251  @username @username @username @username #Yunan...     Bekir
#
#              uploaded_at     konu             tweet_id     dil  kategori_count
# 0    2024-02-24T15:56:32   Arabic  1659141226585571331     NaN               2
# 1    2023-11-14T07:57:28   Arabic  1659158751507521537     NaN               2
# 2    2023-11-14T07:57:40  Arabian  1658061958652755968  Türkçe               1
# 3    2023-08-25T19:01:15  Arabian  1658543138355461888  Türkçe               1
# 4    2023-08-17T21:14:31  Arabian  1658150712864387072  Türkçe               1
# ..                   ...      ...                  ...     ...             ...
# 247  2023-02-01T17:44:12    Tr-Gr  1568670348182265857  Türkçe               1
# 248  2023-01-10T20:01:33    Tr-Gr  1530572228701704193     NaN               2
# 249  2023-07-22T20:25:42    Tr-Gr  1559088833341411330  Türkçe               1
# 250  2023-03-22T10:38:48    Tr-Gr  1522835116254547969  Türkçe               1
# 251  2023-03-22T10:32:48    Tr-Gr  1568685152967991297  Türkçe               1
#
# [252 rows x 12 columns]

# %%
translations = {
    'Göçmen/Mülteci Karşıtı': 'Immigrant/Refugee',
    'Yunan Karşıtı': 'Greek',
    'Yahudi Karşıtı': 'Jew',
    'Ermeni Karşıtı': 'Armenian',
    'Arap Karşıtı': 'Arab',
    'LGBTI+ Karşıtı': 'LGBTI+',
    'Kürt Karşıtı': 'Kurdish',
    'Alevi Karşıtı': 'Alevi'
}

samples['target'] = samples['genel_tutum'].map(translations)

# %%
targets = samples['target'].unique()
targets
# Out:
# array([nan, 'Arab', 'Armenian', 'Immigrant/Refugee', 'Jew', 'Greek'],
#       dtype=object)

# %%
samples['model_input'] = samples.apply(lambda x: f"Tweet id: {x['tweet_id']}, Target: {x['target']}, Text: {x['tweet_text']}", axis=1)

# %%
samples = samples.dropna(subset=['target'])
samples['target'].value_counts()
# Out:
# Arab                 50
# Armenian             50
# Immigrant/Refugee    50
# Jew                  50
# Greek                50
# Name: target, dtype: int64

# %%
print(samples[samples['target'] == 'Jew']['model_input'].str.cat(sep='\n'))
# Out:
# Tweet id: 1555925857637699585, Target: Jew, Text: Ey İnsanlık Nerdesin❓
# Ey Dünya Niye Sessizsin❓
#
# İsrail ordusunun, #Gazze’ye yönelik saldırıları devam ediyor❗
#
# Saldırılarda aralarında 5 yaşında bir çocuğun da buluduğu 12 masum hayatını kaybetti, 84 kardeşimiz de yaralandı.
#
# İsrail'i Şiddetle Kınıyorum.
#
# #GazzeAtesAltında https://t.co/FJAlBLNuJZ
# Tweet id: 1556025770488774658, Target: Jew, Text: Çocuk katilleri!
# Lanetli kavim!
# Çöllere düşün son kez ve bir daha çıkamayın.
#
# #GazaUnderAttack
# #GazzeAtesAltında
# #Gazze
# Tweet id: 1473971550542090246, Target: Jew, Text: Bu itrail her seyiyle insanlığın yüzkarasi. #RobertMaloneYalnızDeğilsin https://t.co/6NY2XiLpQ6
# Tweet id: 1393308652879196160, Target: Jew, Text: 15 SANİYEDE NELER OLUR😌
#
# İşgalci #Teröristİsrail’in #Gazze Şeridi‘ne yönelik yoğun bombardıman devam ediyor
#
# Uyanma vakti!
# Filistin yalnız değildir.
#
# #WakeUp
# #GazzaUnderAttack
# #GenocideinGaza
# @username @username
# #FilistinYalnızDeğil #MilletinAdamı https://t.co/Rcj05Yhu6t
# Tweet id: 1394653950444457988, Target: Jew, Text: Kadınlarla çocuklar da baskaldırdıysa artık yeryüzunden silinme vaktin gelmiştir Allahın izniyle itrail https://t.co/CZjLSmRHTZ
# Tweet id: 1392252623902978049, Target: Jew, Text: @username #Yıkılsınİsrail
# #Kahrolsunİsrail
# #Yansınİsrail
# #ALLAHINNALETİİSRAİLİNÜZERİNEOLSUNİNŞALLAH
# #israilteroerdevletidir
# 😭😭😭
# Tweet id: 1396173840548466688, Target: Jew, Text: #الأقصى_يستصرخ_الجيوش
# #AqsaCallsPakArmy
# #Aqsa_calls_armies
# #AqsaCallsArmies
# #OrdularAksaya https://t.co/LX3gbt80y9
# Tweet id: 1392494449675145217, Target: Jew, Text: #AllahbelanıversinİSRAİL https://t.co/L4B00y31yE
# Tweet id: 1393467610600288257, Target: Jew, Text: Selamün Aleyküm #Türkiye'm
# Günümüz Aydın Gönlümüz Huzurla Dolsun
# Rabbim Mübarek Günlerde Soysuz #Katilİsrail #Soykırımcıİsrail
# #SoyunKurusunİsrail'i Kahru Perişan Eylesin İnşallah
# #Amin https://t.co/Pjl9bj0K8q
# Tweet id: 1392992979485446145, Target: Jew, Text: Miraca şahitlik ettirdiğin Kudüs’ün, özgürlüğüne de bizleri şahit kıl Allahım.
# Allah'ın gazabı zalimlerin üzerine olsun
# YA KAHHAR
# #GenocideinGaza
# #GazzedeKatliamVar
# #GazaUnderAttack https://t.co/AQPvPPDJIO
# Tweet id: 1393484053677056001, Target: Jew, Text: Şehadetin mübarek olsun cennet kuşu🕊
# @yahyazned
#
# #freepalestine🇵🇸
# #freequds🇵🇸
# #freegaza🇵🇸
# #gazaunderattack
# #gazzedekatliamvar
# #المسجد_الأقصى
#
# #işgalciisrail
# #i̇sraildevletdeğildir
# #siyonistisrail
# #israelterrorist
# #soysuzisrailkopekleri https://t.co/Wv7UGYKHfQ
# Tweet id: 1393671699623723010, Target: Jew, Text: Allah ın gazabı  üzerine olsun..İsrail kendi kanında boğül inşaallah yakahar yakahar
# #Katilİsrail https://t.co/UsdQ4sIVpS
# Tweet id: 1394971396929896448, Target: Jew, Text: @username Bu ve bütün fotografları aklınıza kazıyın asla unutmayın ve ne olursa olsun yahudi itlerine asla merhamet göstermeyin! Bir gün itrail yok olunca oradaki yahudi itlerine yapacaklarımızı düşünemiyorum bile 🇹🇷🇵🇸
# Tweet id: 1392833730495107078, Target: Jew, Text: @username @username Bunların hepsi şerefsiz numara yapıyorlar bak filistin saldırıyor algısı #Katilİsrail
# Tweet id: 1391693183155904515, Target: Jew, Text: Ya Rabbi sen katından yardımcılarınla İsrail barbarlarının zulmüne son ver, bizleri de yardımcıların içerisinde bir nefer eyle #OrdularAksaya
# Tweet id: 1515156707390984193, Target: Jew, Text: İngilizi siyonisti hiç rahat durmaz bu alçaklardan dost müttefik olmaz alçakların sözüne itibar edilmez #GözümüzKulağımızAksada
# Tweet id: 1391920935343636483, Target: Jew, Text: Çocukların öldüğü hiçbir dava haklı değildir #Katilİsrail https://t.co/WrGcP9aKdS
# Tweet id: 1393264750969163780, Target: Jew, Text: Binlerce Ürdün'lü kardeşimiz #Filistin sınırına akın ediyor...
# İnşallah,
# Cumhurbaşkanımız Sn. @username’ın güçlü Liderliği ve öncülüğünde yürüttüğü yoğun Diplomasi ve çabalar neticesinde İslam ümmeti birleşir Terör devleti #Katilİsrail'in sonu gelir.🇹🇷🇦🇿
# https://t.co/q5f8NUX4WO
# Tweet id: 1393909569798213634, Target: Jew, Text: KAHROLSUN İSRAİL #FreePalestine #GazaUnderAttack #FilistinYalnizDegil #DünyaFilistininYanında
# Tweet id: 1498727839524429831, Target: Jew, Text: @username Amin amin amin. 🤲
# #FreePalestine #Katilİsrail
# Tweet id: 1392474492610433024, Target: Jew, Text: #MescidiAksadaBaskınVar
# #MescidiAksaOnurumuzdur
# #Teröristisrail https://t.co/5kCnUoa7WC
# Tweet id: 1394185880932429825, Target: Jew, Text: Adı: Şeyma
# Filistinli bir Hâfız.
# 1 yıl sonra Diş Doktoru olacak, Bayram’dan sonra ise evlenecekti.
#
# Ancak İsrail, Şeyma'nın evini savaş uçakları ile bombaladı. Şeyma ve ailesi (12 kişi) şehit oldular.
# #katilisrail #thekillerisrael
# #filistin #gazze
# #SonDakika
#
# #HopeToGaza https://t.co/Lg0iETa0Ov
# Tweet id: 1393434648647192577, Target: Jew, Text: #KudüseYürüyoruz SPONSORU ŞEYTAN OLAN KATİL, SİYONİST, İŞGALCİ israilin EBEDİ YURDU CEHENNEMDİR KUDUS İSLAMDIR SONSUZA KADAR DA İSLAM KALACAK  ...   #FilistinYalnızDeğil
# Tweet id: 1557968706315190277, Target: Jew, Text: @username @username @username Vatansız olmak nasıl bir duygu?
# Gerçekten merak ediyorum açıklar mısın?
# Ya da vatanınız var da biz mi bilmiyoruz. Pensilvanya'nın olduğu ABD mi, yoksa itrail mi?
# İnsanların yatak odalarını ifşa eden cevheri nerenin insanı?
# Müslümanlıkta var mı bu kaset, şantaj montaj işleri?
# Tweet id: 1392613428691357699, Target: Jew, Text: Netenyahunun emri ile halka silah dagıtıldıgı,yahudilerin sokak aralarinda gördüğü filistinlilere ateş ettiği rapor ediliyorDünya israil ve Filistindeki duruma resmen seyirci kalmayı seçiyor.Bu vahşet israilin bu saldırgan tutumu karşısında ciddi adımlar atılmalı
# #Katilİsrail https://t.co/SMrvKSduEC
# Tweet id: 1458303659641540608, Target: Jew, Text: Bu #itrail'liler ne yapıyor böyle? 🤔 https://t.co/1HzDXOHD8g
# Tweet id: 1557215313791442945, Target: Jew, Text: @username #İsrailHaddiniBil  🔥😡🔥
# Tweet id: 1397241789145300999, Target: Jew, Text: Mescid-i Aksa ve Kudüs sevdalısı STK ların oluşturduğu Kudüs Platformunun düzenlemiş olduğu "ÖZGÜR KUDÜS YÜRÜYÜŞÜNE" katıldık. #kahrolsunisrail @username @username @username https://t.co/BdB6CWxf3Z
# Tweet id: 1392492782338596864, Target: Jew, Text: #FreePalestine
# #AksadaBaskınVar
# #ShameOnYouIsrael
# #انقذوا_حي_الشيخ_جراح
# #GazaUnderAttack
# #savesheikhjarrah
# #AlAqsaUnderAttack
# #GazaFightsBack
# #SavePalestine
# #IsraeliTerrorism
# #IsraeliCrimes
# #israelusesphosphorusbombs
# #FacebookSupportIsraelOccupation https://t.co/TZLlmUsfbS
# Tweet id: 1393864800300580867, Target: Jew, Text: Dua dua dua #SonunGeldiKöpekİsrail
# Tweet id: 1393078421064929280, Target: Jew, Text: #KuduesKanAğlıyor
# #Israel
# #isgalciTeroeristİsrail
# İtrailler!
# Sonunuz yakındır İnnşşAllahh 😠
# Tweet id: 1391187031972270080, Target: Jew, Text: @mifbgr @eurodolar1980x @BekirBu02487130 Ne o ağırınamı gittide hakaret ediyorsun inşallah öyledir öylede olur de ama senin kalbin niyetin itrail diye atıyorsa o başka
# Tweet id: 1392876146929414145, Target: Jew, Text: @username #KuduesBizimdir
# #kahrolsunisraill
# #GazaUnderAttack
# #Palestine
# #Kuduesİslamındır
# #IsraelliTerrorism
# #GazaUnderAttack
# Tweet id: 1391057619809341446, Target: Jew, Text: Gevşeklik göstermeyin, üzülmeyin; eğer inanmışsanız şüphesiz en üstün olan sizsiniz.
#
# Ali İmran 139
#
# #OrdularAksaya
# Tweet id: 1390786231336939523, Target: Jew, Text: Elbet birgün inşaAllah...
#
# #kahrolsunisrail
# #Kahrolsunİsrail https://t.co/vLpuehol5f
# Tweet id: 1555835005770911744, Target: Jew, Text: Katil İsrail dün gece yine hiçbir ayrım yapmadan sivillere saldırdı. Hayatını kaybeden kardeşlerimizden biri de 5 yaşındaki Alaa…
#
# Çocuk katili İsrail’in saldırılarını şiddetle kınıyorum.
# Rabbim Filistinli kardeşlerimizin yâr ve yardımcısı olsun.
# #Katilisrail https://t.co/kPjMFHJ1JA
# Tweet id: 1392554620711485440, Target: Jew, Text: Başka söze gerek yok. #katilisrail
# Tweet id: 1390786503752699910, Target: Jew, Text: @username #kahrolsunisrail
# İsrail bir terör devletidir.
# Sonu gelen köpek cami duvarına pislermiş.
# Allah İsrail'i kahru perişan eylesin inşallah.
# Tweet id: 1391549459633524737, Target: Jew, Text: @suleakrte @UyandirmaSer06 Yaklaşıyor yaklaşmakta olan ey teroris itrail ozaman bak kim oynayacacak
# Tweet id: 1515724584447877130, Target: Jew, Text: İşgalci yahudi varlığının saldırılarını durduracak açıklama geldi.! Bu saatten sonra artık  ABD ve "İsrail" düşünsün.!
# #GözümüzKulağımızAksada
# #OrdularAksaya https://t.co/icpamb458b
# Tweet id: 1392960794988630022, Target: Jew, Text: İsrail işgal güçleri korkularından, #Gazze Şeridi yakınlarındaki işgalci yerleşim yerlerinde işgalci yerleşimcilerden sığınaklarda kalmalarını istiyor.
#
# #GazaUnderAttack #Gaza #GazaCity #GazaChildrenUnderAttack #IsraeliTerrorism #IsraelTerrorist  #katilisrail
# Tweet id: 1556599459353608193, Target: Jew, Text: #kahrolisrail
# Tweet id: 1394405008876220424, Target: Jew, Text: - Lübnan'dan atılan üç füze, Filistin-Lübnan sınırında bir yerleşim yerine düştü.
#
# - İsrail saldırıya karşılık Lübnan’ı top atışlarıyla vurdu.
#
# - Sınırda İsrail savaş uçakları uçuyor.
#
# #HearGaza
# #GazzedeSoykırım
# #GazzeDireniyor
# #GazzedeKatliamVar
# #katilisrail
# #GazzeAtesAltinda
# Tweet id: 1392656703288758273, Target: Jew, Text: Yok olacaksın iTrail !!!
#  https://t.co/1zh4jgzNc5
# Tweet id: 1396171718687969280, Target: Jew, Text: @username Memleket teki itrail li fetoş çu pkk lı hepsi ip. İle cehape de toplanmış ondan
# Tweet id: 1392282696911626242, Target: Jew, Text: Bu kez, İigalci, itrail terörist örgüte gereken ders verilecek.
#
# Dananın kuyruğu kopacak..
#
# Allah senden razı olsun @username
# Tweet id: 1390818466777665536, Target: Jew, Text: Yok yok yazarak çizerek olmaz.
# Gögüs göğüse çarpışmalı, ümüğü sıkılmalı, nefesi kesilmeli❗
# Yıkılasın #Israel #israil
#
# #KuduesBizimdir #Kudues #KuduesBizimdir #MescidiAksa #MescidiAksaKırmızıCizgimizdir #MescidiAksaBaskını #Kudus
# #Terroristisrael #Terroristisrael https://t.co/Gw1JfJT8xz
# Tweet id: 1393898142509109252, Target: Jew, Text: #الأقصى_يستصرخ_الجيوش
# #Aqsa_calls_armies
# #AqsaCallsArmies
# #OrdularAksaya
# #IsraelPenjajah
# #IsraelTerrorists
# Quote Tweet https://t.co/zN3cZWrR9s
# Tweet id: 1392944987680169990, Target: Jew, Text: @username Baby killer israel !!
# #IsraeliTerrorism
# #AqsaUnderAttack #isrealterrorıst
# #FreePalestine
# #Killerİsrael
# #GazzedeKatliamVar #IsraelTerrorist
#  #FreeQuds #GazaUnderAttack #Katilİsrail
# #AksadaBaskinVar #AksadaZulumVar #katilnetanyahu #FilistininYanındayız #KudüseBayramGelsin https://t.co/mseOrEaDsc
# Tweet id: 1391384398348627975, Target: Jew, Text: @username #ordularkudüse #OrdularAksaya

# %%
for target in samples['target'].unique(): # ['Alevi', 'Kurdish', 'Armenian', 'LGBTI+', 'Arab', 'Greek', 'Jew']
    text = samples[samples['target'] == target]['model_input'].str.cat(sep='\n')
    output = query_gpt(text)
    with open(f'../data/gpt4o_outputs/{target.replace("/", "-")}_v3.json', 'w', encoding='utf-8') as f:
        f.write(output)

# %%
# dictionary to tweet id to text
id2text = samples.set_index('tweet_id')['tweet_text'].to_dict()

# %%
from pathlib import Path    
import json 
for target in samples['target'].unique():
    print(target)
    with open(f'../data/gpt4o_outputs/{target.replace("/", "-")}_v3.json', 'r', encoding='utf-8') as f:
        data = json.load(f)
        for instance in data['hate_speech_instances']:
            tweet_id = instance['tweet']['id']
            try: 
                instance['tweet']['text'] = id2text[int(tweet_id)]
            except KeyError:
                print(f"Tweet id {tweet_id} not found")
    with open(f'../data/span_annotations/{target.replace("/", "-")}_v3.json', 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
# Out:
# Arab
# Armenian
# Immigrant/Refugee
# Jew
# Greek

# %%
import json 
import pandas as pd 


for target in samples['target'].unique():
    print(target)
    records = []
    with open(f'../data/span_annotations/{target.replace("/", "-")}_v3.json', 'r', encoding='utf-8') as f:
        data = json.load(f)
        instances = data['hate_speech_instances']
        for instance in instances:
            try:
                tweet_id = instance['tweet']['id']
                text = instance['tweet']['text']
                spans = instance['tweet']['span']
                span_txt = ",".join([f"{span['text_span']}" for span in spans])
                category_txt = ",".join([f"{span['hate_speech_category']}" for span in spans])
                records.append([tweet_id, target, text, span_txt, category_txt])
            except KeyError:
                print(f"Tweet id {tweet_id} not found")
    df = pd.DataFrame(records, columns=['tweet_id', 'target', 'text', 'span', 'category'])
    df.to_csv(f'../data/span_annotations/{target.replace("/", "-")}_v3.csv', index=False)
# Out:
# Arab
# Armenian
# Immigrant/Refugee
# Jew
# Greek
